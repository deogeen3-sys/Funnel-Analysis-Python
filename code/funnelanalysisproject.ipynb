# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns 
import plotly.graph_objects as go
import matplotlib.pyplot as plt

# %%
customer_journey = pd.read_csv(r"C:\Users\Interface\Downloads\archive (3)\customer_journey.csv")

# %%
customer_journey.tail()
# Out:
#           SessionID     UserID            Timestamp      PageType DeviceType  \
# 12714  session_4996  user_1354  2025-07-11 10:21:00  product_page    Desktop
# 12715  session_4997  user_2646  2025-05-27 19:54:51          home    Desktop
# 12716  session_4998  user_1040  2025-01-07 04:26:16          home     Tablet
# 12717  session_4998  user_1040  2025-01-07 04:26:54  product_page     Tablet
# 12718  session_4999  user_1541  2025-05-24 05:09:58          home     Mobile
#
#        Country ReferralSource  TimeOnPage_seconds  ItemsInCart  Purchased
# 12714  Germany          Email                  77            0          0
# 12715  Germany   Social Media                  57            0          0
# 12716  Germany         Google                 167            0          0
# 12717  Germany         Google                  38            2          0
# 12718  Germany   Social Media                 113            0          0

# %%
customer_journey.shape
# Out:
# (12719, 10)

# %%
customer_journey.dtypes
# Out:
# SessionID             object
# UserID                object
# Timestamp             object
# PageType              object
# DeviceType            object
# Country               object
# ReferralSource        object
# TimeOnPage_seconds     int64
# ItemsInCart            int64
# Purchased              int64
# dtype: object

# %%
for col in customer_journey.columns:
    print(col)
    print(customer_journey[col].unique())
    print(customer_journey[col].nunique())
    print("-" * 50)
# Out:
# SessionID
# ['session_0' 'session_1' 'session_2' ... 'session_4997' 'session_4998'
#  'session_4999']
# 5000
# --------------------------------------------------
# UserID
# ['user_2223' 'user_2192' 'user_1708' ... 'user_1175' 'user_1434'
#  'user_2587']
# 1872
# --------------------------------------------------
# Timestamp
# ['2025-01-20 22:53:34' '2025-02-26 12:57:10' '2025-02-26 12:59:11' ...
#  '2025-01-07 04:26:16' '2025-01-07 04:26:54' '2025-05-24 05:09:58']
# 12713
# --------------------------------------------------
# PageType
# ['home' 'product_page' 'cart' 'checkout' 'confirmation']
# 5
# --------------------------------------------------
# DeviceType
# ['Desktop' 'Tablet' 'Mobile']
# 3
# --------------------------------------------------
# Country
# ['India' 'Germany' 'UK' 'France' 'Australia' 'USA' 'Canada']
# 7
# --------------------------------------------------
# ReferralSource
# ['Social Media' 'Email' 'Google' 'Direct']
# 4
# --------------------------------------------------
# TimeOnPage_seconds
# [ 55  99 121 160 113  49 135 155  26  15 130 145  61 129  93 137 112 153
#   75 116  54  81  31 147  92  42 171 144  77 178 163  47  78 104  51 142
#   58 150  34 119  84  32 167  63 149 176  20  89 151 180  69  33 131 141
#  136 123 108 115  35 128 118 166  57 140 174  95  97 148 173  27 114  43
#   46 162  30  85  94 177  39  25  80 133 102 152 124 146  91  37 138  82
#  120 106  19  66  60  79  67  72 134  74  24  45  29 158  44  86  17  38
#   21 172  28 154  90 126 132 100 111 170 139 164  62  73 179  48 110  40
#   56 165  18  50 157  16 109  22 169  36  65 117 175 143  64  71 161  88
#  168  76  23  53 101 127 122  98 156  41 159  52  83  70  68 105 125 103
#   87  59  96 107]
# 166
# --------------------------------------------------
# ItemsInCart
# [0 4 5 1 2 3]
# 6
# --------------------------------------------------
# Purchased
# [0 1]
# 2
# --------------------------------------------------

# %%
customer_journey.describe()
# Out:
#        TimeOnPage_seconds   ItemsInCart     Purchased
# count        12719.000000  12719.000000  12719.000000
# mean            97.427707      1.138533      0.397044
# std             48.120729      1.689954      0.489304
# min             15.000000      0.000000      0.000000
# 25%             56.000000      0.000000      0.000000
# 50%             98.000000      0.000000      0.000000
# 75%            139.000000      2.000000      1.000000
# max            180.000000      5.000000      1.000000

# %%
customer_journey.isnull().sum()
# Out:
# SessionID             0
# UserID                0
# Timestamp             0
# PageType              0
# DeviceType            0
# Country               0
# ReferralSource        0
# TimeOnPage_seconds    0
# ItemsInCart           0
# Purchased             0
# dtype: int64

# %%
customer_journey.duplicated().sum
# Out:
# <bound method Series.sum of 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12714    False
# 12715    False
# 12716    False
# 12717    False
# 12718    False
# Length: 12719, dtype: bool>

# %%
plt.figure(figsize=(6,8))

sns.boxplot(y=customer_journey["TimeOnPage_seconds"])

plt.title("Box Plot of Time On Page (seconds)")
plt.ylabel("Seconds")

plt.savefig(
    "BoxPlotOfTimeOnPage.png"
)
plt.show()

# %%
customer_journey['Timestamp'] = pd.to_datetime(customer_journey['Timestamp'])

# %%
customer_journey['Date'] = customer_journey['Timestamp'].dt.date
customer_journey['Time'] = customer_journey['Timestamp'].dt.time

# %%
session_level = customer_journey.groupby(['UserID', 'SessionID']).agg(
    Purchased=('Purchased', 'max') 
).reset_index()

# %%
user_metrics = session_level.groupby('UserID').agg(
    TotalSessionsPerUser=('SessionID', 'nunique'),
    PurchaseCountsPerUser=('Purchased', 'sum')
).reset_index()

# %%
customer_journey = customer_journey.merge(user_metrics, on='UserID', how='left')

# %%
customer_journey
# Out:
#           SessionID     UserID           Timestamp      PageType DeviceType  \
# 0         session_0  user_2223 2025-01-20 22:53:34          home    Desktop
# 1         session_1  user_2192 2025-02-26 12:57:10          home     Tablet
# 2         session_1  user_2192 2025-02-26 12:59:11  product_page     Tablet
# 3         session_2  user_1708 2025-06-24 15:40:46          home     Mobile
# 4         session_3  user_2976 2025-06-11 07:21:02          home     Tablet
# ...             ...        ...                 ...           ...        ...
# 12714  session_4996  user_1354 2025-07-11 10:21:00  product_page    Desktop
# 12715  session_4997  user_2646 2025-05-27 19:54:51          home    Desktop
# 12716  session_4998  user_1040 2025-01-07 04:26:16          home     Tablet
# 12717  session_4998  user_1040 2025-01-07 04:26:54  product_page     Tablet
# 12718  session_4999  user_1541 2025-05-24 05:09:58          home     Mobile
#
#        Country ReferralSource  TimeOnPage_seconds  ItemsInCart  Purchased  \
# 0        India   Social Media                  55            0          0
# 1      Germany          Email                  99            0          0
# 2      Germany          Email                 121            0          0
# 3        India         Google                 160            0          0
# 4           UK         Google                 113            0          0
# ...        ...            ...                 ...          ...        ...
# 12714  Germany          Email                  77            0          0
# 12715  Germany   Social Media                  57            0          0
# 12716  Germany         Google                 167            0          0
# 12717  Germany         Google                  38            2          0
# 12718  Germany   Social Media                 113            0          0
#
#              Date      Time  TotalSessionsPerUser  PurchaseCountsPerUser
# 0      2025-01-20  22:53:34                     4                      1
# 1      2025-02-26  12:57:10                     5                      1
# 2      2025-02-26  12:59:11                     5                      1
# 3      2025-06-24  15:40:46                     5                      1
# 4      2025-06-11  07:21:02                     1                      0
# ...           ...       ...                   ...                    ...
# 12714  2025-07-11  10:21:00                     3                      1
# 12715  2025-05-27  19:54:51                     3                      0
# 12716  2025-01-07  04:26:16                     3                      1
# 12717  2025-01-07  04:26:54                     3                      1
# 12718  2025-05-24  05:09:58                     6                      0
#
# [12719 rows x 14 columns]

# %%
customer_journey_grouped = customer_journey.groupby('UserID').agg({
    'TotalSessionsPerUser': 'max',
    'PurchaseCountsPerUser': 'max'
}).reset_index()

customer_journey_grouped
# Out:
#          UserID  TotalSessionsPerUser  PurchaseCountsPerUser
# 0     user_1001                     2                      1
# 1     user_1002                     2                      1
# 2     user_1004                     1                      0
# 3     user_1005                     2                      2
# 4     user_1006                     4                      0
# ...         ...                   ...                    ...
# 1867  user_2997                     5                      0
# 1868  user_2998                     1                      0
# 1869  user_2999                     3                      1
# 1870  user_3000                     3                      3
# 1871  user_3001                     4                      2
#
# [1872 rows x 3 columns]

# %%
print(customer_journey_grouped['TotalSessionsPerUser'].unique())

print(customer_journey_grouped['PurchaseCountsPerUser'].unique())
# Out:
# [ 2  1  4  3  6  7  5  9  8 10]
# [1 0 2 3 4]

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = customer_journey.copy()

# ترتيب البيانات
df = df.sort_values(by=['SessionID', 'Time'])

# تجميع كل Session
session_paths = df.groupby('SessionID')['PageType'].apply(list).reset_index()

# تحويل إلى purchase / not purchase
session_paths['converted'] = session_paths['PageType'].apply(
    lambda x: 1 if 'confirmation' in x else 0
)

counts = session_paths['converted'].value_counts()

labels = ['Not Purchased', 'Purchased']
sizes = [counts.get(0, 0), counts.get(1, 0)]

plt.figure(figsize=(6,6))
plt.pie(
    sizes,
    labels=labels,
    autopct='%1.1f%%',
    startangle=90,
    colors=['#ff6b6b', '#51cf66']
)

plt.title("Purchase vs Non-Purchase Sessions")
plt.axis('equal')
plt.show()

# %%
sns.countplot(
    x='PurchaseCountsPerUser',
    data=customer_journey_grouped
)

plt.title('Distribution of Purchase Counts Per User')
plt.xlabel('Purchase Counts Per User')
plt.ylabel('Number of Users')

plt.show()

# %%
sns.countplot(
    x='TotalSessionsPerUser',
    data=customer_journey_grouped
)

plt.title('Distribution of Total Session Per User')
plt.xlabel('Total Session Per User')
plt.ylabel('Number of Users')

plt.show()

# %%
df = customer_journey.copy()

df = df.sort_values(by=['SessionID', 'Time'])

user_paths = df.groupby('SessionID')['PageType'].apply(list).reset_index()

user_paths['Path'] = user_paths['PageType'].apply(lambda x: " → ".join(x))

top_paths = user_paths['Path'].value_counts().head(5)

plt.figure(figsize=(10,6))
top_paths.plot(kind='barh')

plt.title("Journey By Session")
plt.xlabel("Number of Sessions")
plt.ylabel("Path")

plt.gca().invert_yaxis()
plt.show()

# %%
avg_time = customer_journey.groupby(
    'PageType'
)['TimeOnPage_seconds'].mean()

avg_time.plot(kind='bar')

plt.title('Average Time on Each Page')
plt.xlabel('Page Type')
plt.ylabel('Average Time (seconds)')

plt.show()

# %%
purchase_by_source = customer_journey.groupby(
    'ReferralSource'
)['Purchased'].sum().sort_values(ascending=False)

purchase_by_source.plot(kind='bar')

plt.title('Purchases by Referral Source')
plt.xlabel('Referral Source')
plt.ylabel('Total Purchases')

plt.show()

# %%
Country = customer_journey.groupby(
    'Country'
)['Purchased'].sum().sort_values(ascending=False)

Country.plot(kind='bar')

plt.title('Purchases by Country')
plt.xlabel('Referral Source')
plt.ylabel('Total Purchases')

plt.show()

# %%
customer_journey["PageType"].value_counts().plot.barh(color=['blue', '#f5005a', '#006400', '#9932CC', '#2F4F4F', '#1E90FF' ], title='Funnel Analysis Stages');

# %%
dfgr = customer_journey.groupby('PageType').count()['Purchased'].reset_index().sort_values(by='Purchased',ascending=False)
dfgr.style.background_gradient(cmap='PuOr')
# Out:
# <style type="text/css">
# #T_69c26_row0_col1 {
#   background-color: #2d004b;
#   color: #f1f1f1;
# }
# #T_69c26_row1_col1 {
#   background-color: #9990bf;
#   color: #f1f1f1;
# }
# #T_69c26_row2_col1 {
#   background-color: #c76b0c;
#   color: #f1f1f1;
# }
# #T_69c26_row3_col1 {
#   background-color: #8d4307;
#   color: #f1f1f1;
# }
# #T_69c26_row4_col1 {
#   background-color: #7f3b08;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_69c26">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_69c26_level0_col0" class="col_heading level0 col0" >PageType</th>
#       <th id="T_69c26_level0_col1" class="col_heading level0 col1" >Purchased</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69c26_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_69c26_row0_col0" class="data row0 col0" >home</td>
#       <td id="T_69c26_row0_col1" class="data row0 col1" >5000</td>
#     </tr>
#     <tr>
#       <th id="T_69c26_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_69c26_row1_col0" class="data row1 col0" >product_page</td>
#       <td id="T_69c26_row1_col1" class="data row1 col1" >3987</td>
#     </tr>
#     <tr>
#       <th id="T_69c26_level0_row2" class="row_heading level0 row2" >0</th>
#       <td id="T_69c26_row2_col0" class="data row2 col0" >cart</td>
#       <td id="T_69c26_row2_col1" class="data row2 col1" >1599</td>
#     </tr>
#     <tr>
#       <th id="T_69c26_level0_row3" class="row_heading level0 row3" >1</th>
#       <td id="T_69c26_row3_col0" class="data row3 col0" >checkout</td>
#       <td id="T_69c26_row3_col1" class="data row3 col1" >1123</td>
#     </tr>
#     <tr>
#       <th id="T_69c26_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_69c26_row4_col0" class="data row4 col0" >confirmation</td>
#       <td id="T_69c26_row4_col1" class="data row4 col1" >1010</td>
#     </tr>
#   </tbody>
# </table>

# %%
stages = ['Homepage', 'Product Page', 'Cart', 'Checkout', 'confirmation']
values = [5000, 3987, 1599, 1123, 1010]

fig = go.Figure(go.Funnel(
    y=stages,
    x=values,
    textinfo="value+percent initial"
))

fig.update_layout(
    title='E-commerce Funnel Analysis',
    width=900,
    height=500
)

fig.show()

# %%
stages = [ 'Home to Product', 'Product to cart', 'cart to checkout', 'checkout to confirmation']
values = [3987, 1599, 1123, 1010]

conversion_rates = [
    (3987 / 5000) * 100,
    (1599 / 3987) * 100,
    (1123 / 1599) * 100,
    (1010 / 1123) * 100
]

plt.figure(figsize=(10,5))

plt.plot(stages, conversion_rates, marker='o')

plt.title('Conversion Rate Between Funnel Stages')
plt.xlabel('Stages')
plt.ylabel('Conversion Rate %')

plt.ylim(0, 110)

plt.show()

# %%
df = customer_journey.copy()

df['PageType'] = df['PageType'].str.strip().str.lower()
df['DeviceType'] = df['DeviceType'].str.strip().str.lower()

devices = df['DeviceType'].unique()

stages = ['home', 'product_page', 'cart', 'checkout', 'Confirmation']

fig = go.Figure()

for device in devices:
    
    df_d = df[df['DeviceType'] == device]

    home = df_d[df_d['PageType'] == 'home']['UserID'].count()
    product = df_d[df_d['PageType'] == 'product_page']['UserID'].count()
    cart = df_d[df_d['PageType'] == 'cart']['UserID'].count()
    checkout = df_d[df_d['PageType'] == 'checkout']['UserID'].count()
    confirmation = df_d[df_d['PageType'] == 'confirmation']['UserID'].count()

    fig.add_trace(go.Funnel(
        name=device,
        y=stages,
        x=[home, product, cart, checkout, confirmation],
        textinfo="value+percent initial"
    ))

fig.update_layout(
    title="Funnel Analysis by Device Type",
    height=600 , 
    width=1050
)

fig.show()

# %%
df = customer_journey.copy()

df['PageType'] = df['PageType'].str.strip().str.lower()
df['Country'] = df['Country'].str.strip().str.lower()

countries = df['Country'].unique()

stages = ['home', 'product_page', 'cart', 'checkout', 'Confirmation']

fig = go.Figure()

for country in countries:
    
    df_d = df[df['Country'] == country]

    home = df_d[df_d['PageType'] == 'home']['UserID'].count()
    product = df_d[df_d['PageType'] == 'product_page']['UserID'].count()
    cart = df_d[df_d['PageType'] == 'cart']['UserID'].count()
    checkout = df_d[df_d['PageType'] == 'checkout']['UserID'].count()
    confirmation = df_d[df_d['PageType'] == 'confirmation']['UserID'].count()

    fig.add_trace(go.Funnel(
        name=country,
        y=stages,
        x=[home, product, cart, checkout, confirmation],
        textinfo="value+percent initial"
    ))

fig.update_layout(
    title="Funnel Analysis by Countries",
    height=600,
    width=1050
)

fig.show()

# %%
import pandas as pd


customer_journey['Hour'] = pd.to_datetime(
    customer_journey['Time'],
    format='%H:%M:%S',
    errors='coerce'
).dt.hour


customer_journey['TimeSegment'] = pd.cut(
    customer_journey['Hour'],
    bins=[0, 4, 8, 12, 16, 20, 24],
    labels=[
        'Late Night',
        'Early Morning',
        'Morning',
        'Afternoon',
        'Evening',
        'Night'
    ],
    right=False,
    include_lowest=True
)

customer_journey.head()
# Out:
#    SessionID     UserID           Timestamp      PageType DeviceType  Country  \
# 0  session_0  user_2223 2025-01-20 22:53:34          home    Desktop    India
# 1  session_1  user_2192 2025-02-26 12:57:10          home     Tablet  Germany
# 2  session_1  user_2192 2025-02-26 12:59:11  product_page     Tablet  Germany
# 3  session_2  user_1708 2025-06-24 15:40:46          home     Mobile    India
# 4  session_3  user_2976 2025-06-11 07:21:02          home     Tablet       UK
#
#   ReferralSource  TimeOnPage_seconds  ItemsInCart  Purchased        Date  \
# 0   Social Media                  55            0          0  2025-01-20
# 1          Email                  99            0          0  2025-02-26
# 2          Email                 121            0          0  2025-02-26
# 3         Google                 160            0          0  2025-06-24
# 4         Google                 113            0          0  2025-06-11
#
#        Time  TotalSessionsPerUser  PurchaseCountsPerUser  Hour    TimeSegment
# 0  22:53:34                     4                      1    22          Night
# 1  12:57:10                     5                      1    12      Afternoon
# 2  12:59:11                     5                      1    12      Afternoon
# 3  15:40:46                     5                      1    15      Afternoon
# 4  07:21:02                     1                      0     7  Early Morning

# %%
df = customer_journey.copy()

df['PageType'] = df['PageType'].str.strip().str.lower()
df['TimeSegment'] = df['TimeSegment'].str.strip().str.lower()

Segments = df['TimeSegment'].unique()

stages = ['home', 'product_page', 'cart', 'checkout', 'Confirmation']

fig = go.Figure()

for Segment in Segments:
    
    df_d = df[df['TimeSegment'] == Segment]

    home = df_d[df_d['PageType'] == 'home']['UserID'].count()
    product = df_d[df_d['PageType'] == 'product_page']['UserID'].count()
    cart = df_d[df_d['PageType'] == 'cart']['UserID'].count()
    checkout = df_d[df_d['PageType'] == 'checkout']['UserID'].count()
    confirmation = df_d[df_d['PageType'] == 'confirmation']['UserID'].count()

    fig.add_trace(go.Funnel(
        name=Segment,
        y=stages,
        x=[home, product, cart, checkout, confirmation],
        textinfo="value+percent initial"
    ))

fig.update_layout(
    title="Funnel Analysis by Time Segment",
    height=600,
    width=1050
)

fig.show()
